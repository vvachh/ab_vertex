# %%
import numpy as np
import matplotlib.pyplot as plt
from vertex_model_ab import VertexModelApicoBasal
from vertex_model_2d import VertexModel
from voronoi_cells import random_voronoi_cells

# %%
locs,adjs = random_voronoi_cells(5)

# %%
vm2d = VertexModel(locs,adjs)
vm2d.show_model(); plt.show()
print 'Initial energy:',vm2d.total_mechanical_energy()
print 'rosettes:',vm2d.find_rosettes(0.01)
vm2d.gradient_descent_with_t1(0.00001,0.0001,0.01)
vm2d.show_model(); plt.show()
print 'Final energy:',vm2d.total_mechanical_energy()
print 'rosettes:',vm2d.find_rosettes(0.01)
# Out:
# Initial energy: 87.8402661674
# rosettes: [[16, 34], [45, 46]]
# total T1 transitions: 2
# Final energy: 73.9449878419
# rosettes: []

# %%
vmab = VertexModelApicoBasal(locs,adjs,0.0)
vmab.show_model()
print 'Initial energy:',vmab.combined_energy()
ap_ros,bas_ros,shared_ros = vmab.classify_rosettes(0.01)
print 'apical rosettes:',ap_ros
print 'basal rosettes:',bas_ros
print 'shared rosettes:',shared_ros
vmab.gradient_descent_with_t1(0.0001,0.001,0.01)
plt.figure()
vmab.show_model()
print 'Final energy:',vmab.combined_energy()
ap_ros,bas_ros,shared_ros = vmab.classify_rosettes(0.01)
print 'apical rosettes:',ap_ros
print 'basal rosettes:',bas_ros
print 'shared rosettes:',shared_ros
# Out:
# Initial energy: 84.5754561109
# apical rosettes: []
# basal rosettes: []
# shared rosettes: [[15, 16], [48, 49]]
# total T1 transitions: 20
# Final energy: 77.3088505872
# apical rosettes: []
# basal rosettes: []
# shared rosettes: []

# %%
vmab = VertexModelApicoBasal(locs,adjs,0.2)
vmab.show_model()
print 'Initial energy:',vmab.combined_energy()
ap_ros,bas_ros,shared_ros = vmab.classify_rosettes(0.01)
print 'apical rosettes:',ap_ros
print 'basal rosettes:',bas_ros
print 'shared rosettes:',shared_ros
vmab.gradient_descent_with_t1(0.0001,0.001,0.01)
plt.figure()
vmab.show_model()
print 'Final energy:',vmab.combined_energy()
ap_ros,bas_ros,shared_ros = vmab.classify_rosettes(0.01)
print 'apical rosettes:',ap_ros
print 'basal rosettes:',bas_ros
print 'shared rosettes:',shared_ros
# Out:
# Initial energy: 77.4571931108
# apical rosettes: [[0, 3]]
# basal rosettes: []
# shared rosettes: [[15, 16], [48, 49]]
# total T1 transitions: 16
# Final energy: 72.5768679716
# apical rosettes: [[18, 45]]
# basal rosettes: []
# shared rosettes: []

# %%
vmab = VertexModelApicoBasal(locs,adjs,0.5)
vmab.show_model()
print 'Initial energy:',vmab.combined_energy()
ap_ros,bas_ros,shared_ros = vmab.classify_rosettes(0.01)
print 'apical rosettes:',ap_ros
print 'basal rosettes:',bas_ros
print 'shared rosettes:',shared_ros
vmab.gradient_descent_with_t1(0.0001,0.001,0.01)
plt.figure()
vmab.show_model()
print 'Final energy:',vmab.combined_energy()
ap_ros,bas_ros,shared_ros = vmab.classify_rosettes(0.01)
print 'apical rosettes:',ap_ros
print 'basal rosettes:',bas_ros
print 'shared rosettes:',shared_ros
# Out:
# Initial energy: 82.085947294
# apical rosettes: [[0, 3]]
# basal rosettes: []
# shared rosettes: [[15, 16], [48, 49]]
# total T1 transitions: 12
# Final energy: 80.5679365133
# apical rosettes: [[18, 45]]
# basal rosettes: [[15, 16], [48, 49]]
# shared rosettes: []

# %%
vmab = VertexModelApicoBasal(locs,adjs,0.8)
vmab.show_model()
print 'Initial energy:',vmab.combined_energy()
ap_ros,bas_ros,shared_ros = vmab.classify_rosettes(0.01)
print 'apical rosettes:',ap_ros
print 'basal rosettes:',bas_ros
print 'shared rosettes:',shared_ros
vmab.gradient_descent_with_t1(0.00005,0.0005,0.01)
plt.figure()
vmab.show_model()
print 'Final energy:',vmab.combined_energy()
ap_ros,bas_ros,shared_ros = vmab.classify_rosettes(0.01)
print 'apical rosettes:',ap_ros
print 'basal rosettes:',bas_ros
print 'shared rosettes:',shared_ros
# Out:
# Initial energy: 97.7829911999
# apical rosettes: [[0, 3]]
# basal rosettes: []
# shared rosettes: [[15, 16], [48, 49]]
# total T1 transitions: 8
# Final energy: 97.2130425311
# apical rosettes: [[0, 3], [18, 45]]
# basal rosettes: [[15, 16], [48, 49]]
# shared rosettes: []

# %%
vmab = VertexModelApicoBasal(locs,adjs,0.0)
vmab.show_model()
print 'Initial energy:',vmab.combined_energy()
vmab.gradient_descent_with_t1(0.0005,0.005,0.01)
plt.figure()
vmab.show_model()
print 'Final energy:',vmab.combined_energy()
# Out:
# Initial energy: 78.6287141865
# total T1 transitions: 0
# Final energy: 71.1667907753

# %%
x = [1,2,4,3]
x.pop(1)
x
# Out:
# [1, 4, 3]
